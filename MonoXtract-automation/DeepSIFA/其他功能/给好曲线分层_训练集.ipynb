# %%
import pandas as pd

# 读取CSV文件
input_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score.csv'
output_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good.csv'

# 读取CSV文件
df = pd.read_csv(input_file_path)

# 筛选出label列值为0的行
filtered_df = df[df['label'] == 0]

# 将筛选后的数据另存为新的CSV文件
filtered_df.to_csv(output_file_path, index=False)

print(f"Filtered data with label 0 has been saved to {output_file_path}")
# Out:
# Filtered data with label 0 has been saved to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good.csv

# %%
import pandas as pd

# 读取CSV文件
input_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good.csv'
output_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good_.csv'

# 读取CSV文件
df = pd.read_csv(input_file_path)

# 修改name列中以.npz结尾的值为.png结尾
df['name'] = df['name'].str.replace('.npz', '.png')

# 将修改后的数据另存为新的CSV文件
df.to_csv(output_file_path, index=False)

print(f"Modified data has been saved to {output_file_path}")
# Out:
# Modified data has been saved to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good_.csv
# /tmp/ipykernel_14256/3508279081.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['name'] = df['name'].str.replace('.npz', '.png')

# %%
import os
import pandas as pd
import shutil

# 读取CSV文件
input_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good_.csv'
source_dir = '/home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1'
destination_dir = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0-0.3'

# 创建目标目录（如果不存在）
os.makedirs(destination_dir, exist_ok=True)

# 读取CSV文件
df = pd.read_csv(input_file_path)

# 筛选score列值在0到0.3范围内的行
filtered_df = df[(df['score'] >= 0) & (df['score'] < 0.3)]

# 复制文件到目标目录
for file_name in filtered_df['name']:
    # 构建源文件路径和目标文件路径
    source_file_path = os.path.join(source_dir, file_name)
    destination_file_path = os.path.join(destination_dir, file_name)
    
    # 复制文件
    if os.path.exists(source_file_path):
        shutil.copy(source_file_path, destination_file_path)
        print(f"Copied {source_file_path} to {destination_file_path}")
    else:
        print(f"File {source_file_path} does not exist")

print(f"Files with score between 0 and 0.3 have been copied to {destination_dir}")
# Out:
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_2_130_good_sc1.4_77_794.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0-0.3/AlphaK10_2_130_good_sc1.4_77_794.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_107_good_sc1.2_177_997.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0-0.3/AlphaK10_3_107_good_sc1.2_177_997.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_61_good.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0-0.3/AlphaK10_3_61_good.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_1_32_good.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0-0.3/AlphaK10_1_32_good.png
# ...

# %%
import os
import pandas as pd
import shutil

# 读取CSV文件
input_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good_.csv'
source_dir = '/home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1'
destination_dir = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.3-0.6'

# 创建目标目录（如果不存在）
os.makedirs(destination_dir, exist_ok=True)

# 读取CSV文件
df = pd.read_csv(input_file_path)

# 筛选score列值在0到0.3范围内的行
filtered_df = df[(df['score'] >= 0.3) & (df['score'] < 0.6)]

# 复制文件到目标目录
for file_name in filtered_df['name']:
    # 构建源文件路径和目标文件路径
    source_file_path = os.path.join(source_dir, file_name)
    destination_file_path = os.path.join(destination_dir, file_name)
    
    # 复制文件
    if os.path.exists(source_file_path):
        shutil.copy(source_file_path, destination_file_path)
        print(f"Copied {source_file_path} to {destination_file_path}")
    else:
        print(f"File {source_file_path} does not exist")

print(f"Files with score between 0.3 and 0.6 have been copied to {destination_dir}")
# Out:
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_92_good_sc1.8_448_653.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.3-0.6/AlphaK10_3_92_good_sc1.8_448_653.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_2_37_good.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.3-0.6/AlphaK10_2_37_good.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_2_92_good.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.3-0.6/AlphaK10_2_92_good.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_62_good_sc1.8_185_1005.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.3-0.6/AlphaK10_3_62_good_sc1.8_185_1005.png
# ...

# %%
import os
import pandas as pd
import shutil

# 读取CSV文件
input_file_path = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/score_good_.csv'
source_dir = '/home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1'
destination_dir = '/home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.6-1'

# 创建目标目录（如果不存在）
os.makedirs(destination_dir, exist_ok=True)

# 读取CSV文件
df = pd.read_csv(input_file_path)

# 筛选score列值在0到0.3范围内的行
filtered_df = df[(df['score'] >= 0.6) & (df['score'] <= 1)]

# 复制文件到目标目录
for file_name in filtered_df['name']:
    # 构建源文件路径和目标文件路径
    source_file_path = os.path.join(source_dir, file_name)
    destination_file_path = os.path.join(destination_dir, file_name)
    
    # 复制文件
    if os.path.exists(source_file_path):
        shutil.copy(source_file_path, destination_file_path)
        print(f"Copied {source_file_path} to {destination_file_path}")
    else:
        print(f"File {source_file_path} does not exist")

print(f"Files with score between 0.6 and 1 have been copied to {destination_dir}")
# Out:
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_1_53_good.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.6-1/AlphaK10_1_53_good.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_5_good_sc1.5_348_963.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.6-1/AlphaK10_3_5_good_sc1.5_348_963.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_8_good.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.6-1/AlphaK10_3_8_good.png
# Copied /home/node01/linchen/data/alphaK10/V2/汇总/1+2+3_数据增强_修改后/归一化插值后npz_1024_高斯平滑1/png1/AlphaK10_3_8_good_sc1.3_158_773.png to /home/node01/linchen/Alphak10_trans_v3_new_v4.1_修改后/logs_train验证/fold5/good0.6-1/AlphaK10_3_8_good_sc1.3_158_773.png
# ...
